# %%
import pandas as pd 
df= pd.read_csv('titanic_train.csv')
print(df)
# Out:
#      Unnamed: 0.1  Unnamed: 0  PassengerId  Survived  Pclass  \
# 0               0           0            1         0       3
# 1               1           1            2         1       1
# 2               2           2            3         1       3
# 3               3           3            4         1       1
# 4               4           4            5         0       3
# ..            ...         ...          ...       ...     ...
# 886           886         886          887         0       2
# 887           887         887          888         1       1
# 888           888         888          889         0       3
# 889           889         889          890         1       1
# 890           890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df[df.Age<25]
# Out:
#      Unnamed: 0.1  Unnamed: 0  PassengerId  Survived  Pclass  \
# 0               0           0            1         0       3
# 7               7           7            8         0       3
# 9               9           9           10         1       2
# 10             10          10           11         1       3
# 12             12          12           13         0       3
# ..            ...         ...          ...       ...     ...
# 875           875         875          876         1       3
# 876           876         876          877         0       3
# 877           877         877          878         0       3
# 882           882         882          883         0       3
# 887           887         887          888         1       1
#
#                                     Name     Sex   Age  SibSp  Parch  \
# 0                Braund, Mr. Owen Harris    male  22.0      1      0
# 7         Palsson, Master. Gosta Leonard    male   2.0      3      1
# ...

# %%
df.loc[df["Age"] < 25.0,'Age']=25.0
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  PassengerId  Survived  Pclass  \
# 0               0           0            1         0       3
# 1               1           1            2         1       1
# 2               2           2            3         1       3
# 3               3           3            4         1       1
# 4               4           4            5         0       3
# ..            ...         ...          ...       ...     ...
# 886           886         886          887         0       2
# 887           887         887          888         1       1
# 888           888         888          889         0       3
# 889           889         889          890         1       1
# 890           890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  25.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
import pandas as pd 
import numpy as np 
data={'Name':['A','B','C','X','Y','Z'], 
 'Maths':[36.0,39.0,np.nan,78.0,54.0,49.0], 
 'Section':[3.0,2.0,2.0,3.0,np.nan,4.0]} 
de = pd.DataFrame(data) 
de
# Out:
#   Name  Maths  Section
# 0    A   36.0      3.0
# 1    B   39.0      2.0
# 2    C    NaN      2.0
# 3    X   78.0      3.0
# 4    Y   54.0      NaN
# 5    Z   49.0      4.0

# %%
de['Section'] = de['Section'].fillna(de['Section'].value_counts()) 
de
# Out:
#   Name  Maths  Section
# 0    A   36.0      3.0
# 1    B   39.0      2.0
# 2    C    NaN      2.0
# 3    X   78.0      3.0
# 4    Y   54.0      1.0
# 5    Z   49.0      4.0

# %%
de['Maths']=de['Maths'].fillna(de['Maths'].mean())
de
# Out:
#   Name  Maths  Section
# 0    A   36.0      3.0
# 1    B   39.0      2.0
# 2    C   51.2      2.0
# 3    X   78.0      3.0
# 4    Y   54.0      1.0
# 5    Z   49.0      4.0

# %%
survive_mask=df["Survived"]==1 
sex_mask=df["Sex"]=="female" 
age_mask=df["Age"] >= 50 
df[survive_mask & sex_mask & age_mask]
# Out:
#      Unnamed: 0.1  Unnamed: 0  PassengerId  Survived  Pclass  \
# 11             11          11           12         1       1
# 15             15          15           16         1       2
# 195           195         195          196         1       1
# 259           259         259          260         1       2
# 268           268         268          269         1       1
# 275           275         275          276         1       1
# 299           299         299          300         1       1
# 366           366         366          367         1       1
# 458           458         458          459         1       2
# 483           483         483          484         1       3
# 496           496         496          497         1       1
# 513           513         513          514         1       1
# 526           526         526          527         1       2
# 571           571         571          572         1       1
# ...
